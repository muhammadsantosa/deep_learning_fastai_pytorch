# %%
# !pip install -Uqq fastai duckduckgo_search

# %%
from duckduckgo_search import *
from fastcore.all import *
import time

def search_images(name, max_images=200):
    url = 'https://duckduckgo.com/'
    res = urlread(url, data={'q':name})
    searchObj = re.search(r'vqd=([\d-]+)\&', res)
    requestUrl = url + 'i.js'
    params = dict(l='us-en', o='json', q=name, vqd=searchObj.group(1), f=',,,', p='1', v7exp='a')
    urls,data = set(),{'next':1}
    while len(urls)<max_images and 'next' in data:
        data = urljson(requestUrl, data=params)
        urls.update(L(data['results']).itemgot('image'))
        requestUrl = url + data['next']
        time.sleep(0.2)
    return L(urls)[:max_images]

# %%
urls = search_images('bird photos', max_images=1)
urls[0]
# Out:
# 'https://static.straitstimes.com.sg/sites/default/files/24160981_-_22_05_2012_-_rcparks.jpg'

# %%
from fastdownload import download_url

dest = 'bird.jpg'
download_url(urls[0], dest, show_progress=True)

from fastai.vision.all import *

im = Image.open(dest)
im.to_thumb(256, 256)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 from fastdownload import download_url
#       3 dest = 'bird.jpg'
# ----> 4 download_url(urls[0], dest, show_progress=True)
#       6 from fastai.vision.all import *
#       8 im = Image.open(dest)
#
# File /opt/anaconda3/lib/python3.11/site-packages/fastdownload/core.py:19, in download_url(url, dest, timeout, show_progress)
#      17     pbar.total = tsize
#      18     pbar.update(count*bsize)
# ---> 19 return urlsave(url, dest, reporthook=progress if show_progress else None, timeout=timeout)
#
# File /opt/anaconda3/lib/python3.11/site-packages/fastcore/net.py:187, in urlsave(url, dest, reporthook, headers, timeout)
#     185 dest = urldest(url, dest)
#     186 dest.parent.mkdir(parents=True, exist_ok=True)
# --> 187 nm,msg = urlretrieve(url, dest, reporthook, headers=headers, timeout=timeout)
# ...

# %% [markdown]
# - Can do the above in a much shorter manner

# %%
from fastai.vision.all import *

download_url(search_images('forest photos', max_images = 1)[0], 'forest.jpg', show_progress=True)
Image.open('forest.jpg').to_thumb(256, 256)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='6537216' class='' max='6531468' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.09% [6537216/6531468 00:29&lt;00:00]
#     </div>
# <PIL.Image.Image image mode=RGB size=256x144>

# %% [markdown]
# - Now to do it with different setting of birds and forest normal, with sun and without sun

# %%
searches = 'forest', 'bird'
path = Path('bird_or_not')

from time import sleep

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f"{o} photos"))
    sleep(10)
    download_images(dest, urls=search_images(f"{o} sun photos"))
    sleep(10)
    download_images(dest, urls=search_images(f"{o} shade photos"))
    sleep(10)
    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# ---------------------------------------------------------------------------
# HTTP403ForbiddenError                     Traceback (most recent call last)
# Cell In[26], line 11
#       9 download_images(dest, urls=search_images(f"{o} photos"))
#      10 sleep(10)
# ---> 11 download_images(dest, urls=search_images(f"{o} sun photos"))
#      12 sleep(10)
#      13 download_images(dest, urls=search_images(f"{o} shade photos"))
#
# Cell In[2], line 13, in search_images(name, max_images)
#      11 urls,data = set(),{'next':1}
#      12 while len(urls)<max_images and 'next' in data:
# ---> 13     data = urljson(requestUrl, data=params)
#      14     urls.update(L(data['results']).itemgot('image'))
#      15     requestUrl = url + data['next']
#
# File /opt/anaconda3/lib/python3.11/site-packages/fastcore/net.py:132, in urljson(url, data, timeout)
#     130 def urljson(url, data=None, timeout=None):
#     131     "Retrieve `url` and decode json"
# ...

# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 2

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path, bs=32)

dls.show_batch(max_n=32)

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(5)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /Users/rashid/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████████████████████████████████| 44.7M/44.7M [00:02<00:00, 19.3MB/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
# ...

# %%
is_bird,_,probs = learn.predict(PILImage.create('bird.jpg'))
print(f"This is a: {is_bird}.")
print(f"Probability it's a bird: {probs[0]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is a: bird.
# Probability it's a bird: 1.0000
